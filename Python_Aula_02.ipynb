# %% [markdown]
# <a href="https://colab.research.google.com/github/afraniofilho/GB_Python_Irep/blob/main/Python_Aula_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics as st

# %%
dados = [1.23, 1.45, 1.23, 1.22, 1.45, 1.68, 1.56, 1.45, 1.21, 1.45, 1.38, 1.47]

# %%
dados
# Out:
# [1.23, 1.45, 1.23, 1.22, 1.45, 1.68, 1.56, 1.45, 1.21, 1.45, 1.38, 1.47]

# %%
st.mean(dados)
# Out:
# 1.3983333333333332

# %%
st.stdev(dados)
# Out:
# 0.14941299282272083

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('EB.csv')

# %%
df
# Out:
#      Diametro  Ordens     Normal   Pos Skew   Neg Skew    Misterio
# 0        1.25     2.0  76.296173  63.705994  77.100639   76.802063
# 1        1.45     3.0  80.738739  65.795341  70.563339   58.790665
# 2        1.23     2.0  82.474930  66.512024  73.386749   82.533379
# 3        1.22     1.0  87.897156  64.910660  64.891518   71.306450
# 4        1.45     0.0  73.646530  67.237747  76.984497   73.760651
# ..        ...     ...        ...        ...        ...         ...
# 495       NaN     NaN  73.377541  62.921150  72.298492  118.055374
# 496       NaN     NaN  54.317173  82.124977  76.631279  133.694824
# 497       NaN     NaN  64.908524  67.107224  71.980598  133.804810
# 498       NaN     NaN  74.645348  65.141914  76.855118  127.145119
# 499       NaN     NaN  60.578156  64.501343  70.845062  116.213173
#
# [500 rows x 6 columns]

# %%
df.head()
# Out:
#    Diametro  Ordens     Normal   Pos Skew   Neg Skew   Misterio
# 0      1.25     2.0  76.296173  63.705994  77.100639  76.802063
# 1      1.45     3.0  80.738739  65.795341  70.563339  58.790665
# 2      1.23     2.0  82.474930  66.512024  73.386749  82.533379
# 3      1.22     1.0  87.897156  64.910660  64.891518  71.306450
# 4      1.45     0.0  73.646530  67.237747  76.984497  73.760651

# %%
sns.histplot(df, x='Normal', color='red')

# %%
df2 = pd.read_csv('boxplot.csv')

# %%
df2
# Out:
#       Hospital           ALA      Tempo
# 0   HOSPITAL A  Ala Infantil  18.335000
# 1   HOSPITAL A  Ala Infantil  18.510000
# 2   HOSPITAL A  Ala Infantil  18.750000
# 3   HOSPITAL A  Ala Infantil  19.045000
# 4   HOSPITAL A  Ala Infantil  18.832500
# 5   HOSPITAL A  Ala Infantil  19.187500
# 6   HOSPITAL A  Ala Infantil  19.195000
# 7   HOSPITAL A  Ala Infantil  18.685000
# 8   HOSPITAL A  Ala Infantil  18.145000
# 9   HOSPITAL A  Ala Infantil  18.215000
# 10  HOSPITAL A     Geriatria  16.465312
# 11  HOSPITAL A     Geriatria  16.478437
# 12  HOSPITAL A     Geriatria  16.314375
# 13  HOSPITAL A     Geriatria  16.408437
# 14  HOSPITAL A     Geriatria  16.561562
# 15  HOSPITAL A     Geriatria  16.393125
# 16  HOSPITAL A     Geriatria  16.460938
# 17  HOSPITAL A     Geriatria  16.502500
# 18  HOSPITAL A     Geriatria  16.323125
# 19  HOSPITAL A     Geriatria  16.482812
# 20  HOSPITAL B  Ala Infantil  18.982500
# 21  HOSPITAL B  Ala Infantil  19.237500
# ...

# %%
sns.boxplot(y='Hospital', x='Tempo', hue='ALA', orient='horizontal', palette='Set2',data=df2, width=0.8,
             showmeans=True, meanprops={'marker':'>', 'markerfacecolor':'blue', 'markersize':'8'})

# %%
df3 = pd.read_csv('dispersao.csv')

# %%
df3
# Out:
#     Rendimento     Pressao
# 0    68.119850  343.213755
# 1    66.521010  332.409340
# 2    73.905141  368.075840
# 3    69.989601  347.655465
# 4    63.563314  332.764751
# 5    71.622165  345.269734
# 6    64.436368  327.034930
# 7    71.767952  365.275399
# 8    73.662826  348.646993
# 9    68.384627  342.655197
# 10   69.956857  357.839521
# 11   73.773776  360.122237
# 12   73.837035  372.033229
# 13   73.527427  352.900918
# 14   69.678398  353.377565
# 15   71.910303  361.545524
# 16   66.229842  338.352521
# 17   70.960309  343.124664
# 18   66.835970  332.988831
# 19   73.149977  354.991584
# 20   71.059776  350.178288
# 21   71.547714  358.406227
# 22   68.227839  335.744515
# 23   68.187307  344.858074
# 24   72.714201  350.599317
# 25   71.329150  349.086945
# 26   67.108516  333.834727
# 27   61.448787  301.369789
# 28   76.799564  370.180612
# 29   74.158045  364.490816
# 30   66.518783  334.699697
# 31   71.614697  346.865262
# 32   66.506174  335.399182
# ...

# %%
sns.scatterplot(x='Pressao', y='Rendimento', data=df3, marker='>', s=50, color='red')

# %%
# Gerar multiplos gráficos
# 1 linha e 2 colunas
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,6))
sns.histplot(df, x='Normal', color='blue', ax=axes[0])
axes[0].set_title('Histograma', fontsize = '15')
sns.boxplot(x='Hospital', y='Tempo', data=df2, hue='ALA', ax=axes[1], showmeans=True, palette='Reds')
axes[1].set_title('Boxplot', fontsize = '15')
# Out:
# Text(0.5, 1.0, 'Boxplot')
